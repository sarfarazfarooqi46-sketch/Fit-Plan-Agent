# %%
#Travel Agent
#Predefined Rule Base Agent
#Agent for Flights from Karachi to Islamabad, Lahore, Multan

departure_city = input("Enter Departure City: ")
destination_city = input("Enter Destination City: ")


if departure_city == "Karachi" and destination_city == "Lahore":
  print("I've found three available flights for you. ")
  print("Can you tell me your budget?")
  budget = int(input("Enter Your Budget in Rupees:"))
  if budget < 15000:
    print("Sorry, with your budget there is no flight available.")
  if budget >= 15000 and budget <=20000:
    print("There's a flight available for you.")
    print("Departure Time: 10PM")
    print("Arrival Time: 3AM")
    print("Estimate fare: 20,000")
  elif budget <= 30000:
    print("There are two flights available for you.")
    print("1. Estimate fare: 30,000")
    print("   Departure Time: 6PM")
    print("   Arrival Time: 9PM")
    print("2. Estimate fare: 20,000")
    print("   Departure Time: 10PM")
    print("   Arrival Time: 3AM")
  elif budget <= 40000:
    print("There are three flights available for you.")
    print("1. Estimate fare: 36,000")
    print("   Departure Time: 4PM")
    print("   Arrival Time: 6PM")

    print("2. Estimate fare: 28,000")
    print("   Departure Time: 6PM")
    print("   Arrival Time: 9PM")

    print("3. Estimate fare: 20,000")
    print("   Departure Time: 10PM")
    print("   Arrival Time: 3AM")

elif departure_city == "Karachi" and destination_city == "Islamabad":
  print("I've found two available flights for you. ")
  print("Can you tell me your budget?")
  budget = int(input("Enter Your Budget in Rupees:"))
  if budget < 20000:
    print("Sorry, with your budget there is no flight available.")
  elif budget >= 20000 and budget <=30000:
    print("There's a flight available for you.")
    print("Estimate fare: 25,000")
    print("Departure Time: 7PM")
    print("Arrival Time: 12AM")

  elif budget > 30000:
    print("There are two flights available for you.")
    print("1. Estimate fare: 34,000")
    print("   Departure Time: 5PM")
    print("   Arrival Time: 6:30PM")
    print("2. Estimate fare: 25,000")
    print("   Departure Time: 7PM")
    print("   Arrival Time: 12AM")

elif departure_city == "Karachi" and destination_city == "Multan":
  print("I've found one available flights for you. ")
  print("Can you tell me your budget?")
  budget = int(input("Enter Your Budget in Rupees:"))
  if budget < 15000:
    print("Sorry, with your budget there is no flight available.")
  elif budget >= 15000 and budget <=20000:
    print("There's a flight available for you.")
    print("Estimate fare: 19,000")
    print("Departure Time: 5:30PM")
    print("Arrival Time: 8:30PM")
else:
    print("Sorry, there are no available flights from", departure_city,"to", destination_city, "!")
# Out:
# Enter Departure City: Dubai
# Enter Destination City: turkey
# Sorry, there are no available flights from Dubai to turkey !
